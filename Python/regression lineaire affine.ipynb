# %%
import numpy as np
import sklearn
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
x,y=make_regression(n_samples=100,n_features=1,noise=10)
plt.scatter(x,y)

# %%
print (x.shape)
y=y.reshape(y.shape[0],1)
print(y.shape)
# Out:
# (100, 1)
# (100, 1)

# %%
#matrice X
X=np.hstack((x,np.ones(x.shape)))
X
# Out:
# array([[-4.20331775e-01,  1.00000000e+00],
#        [-6.09617928e-01,  1.00000000e+00],
#        [-5.48697320e-01,  1.00000000e+00],
#        [ 4.77324935e-02,  1.00000000e+00],
#        [ 5.30888979e-01,  1.00000000e+00],
#        [-1.31377322e+00,  1.00000000e+00],
#        [-1.01418420e+00,  1.00000000e+00],
#        [ 1.06577029e+00,  1.00000000e+00],
#        [ 6.22796804e-01,  1.00000000e+00],
#        [ 1.23712457e+00,  1.00000000e+00],
#        [-6.59077151e-01,  1.00000000e+00],
#        [-9.59738666e-02,  1.00000000e+00],
#        [-1.37349820e+00,  1.00000000e+00],
#        [-7.47964395e-01,  1.00000000e+00],
#        [-1.26717611e+00,  1.00000000e+00],
#        [ 5.47878847e-01,  1.00000000e+00],
#        [ 2.53282715e-01,  1.00000000e+00],
#        [-1.27702551e+00,  1.00000000e+00],
#        [-8.77964245e-01,  1.00000000e+00],
#        [-4.65740560e-01,  1.00000000e+00],
#        [-8.98555528e-01,  1.00000000e+00],
#        [-1.17119845e+00,  1.00000000e+00],
#        [ 1.67943783e+00,  1.00000000e+00],
#        [ 2.03511270e+00,  1.00000000e+00],
#        [ 5.43603089e-01,  1.00000000e+00],
#        [ 7.09160183e-02,  1.00000000e+00],
#        [-1.17633406e+00,  1.00000000e+00],
#        [ 2.37855123e-04,  1.00000000e+00],
#        [-3.63729261e-01,  1.00000000e+00],
#        [ 1.38859141e-01,  1.00000000e+00],
#        [ 1.58857609e-02,  1.00000000e+00],
#        [-9.68964988e-01,  1.00000000e+00],
#        [-5.99057531e-01,  1.00000000e+00],
#        [-1.69934995e-01,  1.00000000e+00],
#        [-7.68487588e-02,  1.00000000e+00],
#        [-1.39253897e-01,  1.00000000e+00],
#        [-1.87738924e+00,  1.00000000e+00],
#        [-7.13383007e-01,  1.00000000e+00],
#        [ 6.49867034e-01,  1.00000000e+00],
#        [ 1.11403878e+00,  1.00000000e+00],
#        [ 8.28473483e-01,  1.00000000e+00],
#        [ 2.27839181e+00,  1.00000000e+00],
#        [-4.46130552e-01,  1.00000000e+00],
#        [-1.01529892e+00,  1.00000000e+00],
#        [-2.32264716e+00,  1.00000000e+00],
#        [ 6.25078602e-01,  1.00000000e+00],
#        [-1.07209761e+00,  1.00000000e+00],
#        [ 9.05215697e-01,  1.00000000e+00],
#        [ 1.49852498e+00,  1.00000000e+00],
#        [ 7.87455471e-01,  1.00000000e+00],
#        [ 7.63837526e-01,  1.00000000e+00],
#        [-1.05218987e+00,  1.00000000e+00],
#        [-3.52636716e-01,  1.00000000e+00],
#        [ 9.98871413e-01,  1.00000000e+00],
#        [-1.76394558e+00,  1.00000000e+00],
#        [-4.73918944e-01,  1.00000000e+00],
#        [ 3.19143206e-02,  1.00000000e+00],
#        [-1.38954353e+00,  1.00000000e+00],
#        [ 4.35610925e-02,  1.00000000e+00],
#        [-1.97885132e-01,  1.00000000e+00],
#        [-4.45868455e-01,  1.00000000e+00],
#        [ 3.31025356e-01,  1.00000000e+00],
#        [-9.57107927e-01,  1.00000000e+00],
#        [ 1.15023302e-01,  1.00000000e+00],
#        [ 2.97003211e+00,  1.00000000e+00],
#        [-4.51909177e-01,  1.00000000e+00],
#        [ 1.69612370e+00,  1.00000000e+00],
#        [-1.29957080e+00,  1.00000000e+00],
#        [ 8.74875880e-01,  1.00000000e+00],
#        [ 3.33055487e-01,  1.00000000e+00],
#        [ 5.95000960e-02,  1.00000000e+00],
#        [-4.34638799e-01,  1.00000000e+00],
#        [-2.53435047e+00,  1.00000000e+00],
#        [ 1.40613289e+00,  1.00000000e+00],
#        [ 4.21667033e-01,  1.00000000e+00],
#        [-6.12864965e-01,  1.00000000e+00],
#        [ 1.60176179e+00,  1.00000000e+00],
#        [-3.29966234e-01,  1.00000000e+00],
#        [ 1.47352945e+00,  1.00000000e+00],
#        [ 5.73496312e-01,  1.00000000e+00],
#        [-5.09637832e-01,  1.00000000e+00],
#        [-2.93264040e-01,  1.00000000e+00],
#        [-2.00233139e-01,  1.00000000e+00],
#        [ 2.83544315e-01,  1.00000000e+00],
#        [-1.53709850e+00,  1.00000000e+00],
#        [-1.06810601e+00,  1.00000000e+00],
#        [ 8.15024550e-01,  1.00000000e+00],
#        [-9.14005912e-01,  1.00000000e+00],
#        [-1.26326700e+00,  1.00000000e+00],
#        [ 1.57655880e+00,  1.00000000e+00],
#        [-5.44753947e-01,  1.00000000e+00],
#        [-1.65856989e+00,  1.00000000e+00],
#        [ 6.47640104e-01,  1.00000000e+00],
#        [-1.00152366e-02,  1.00000000e+00],
#        [-5.73095681e-01,  1.00000000e+00],
#        [ 2.68826721e-02,  1.00000000e+00],
#        [ 2.17467380e+00,  1.00000000e+00],
#        [ 3.47692127e-01,  1.00000000e+00],
#        [-1.05480583e+00,  1.00000000e+00],
#        [-1.91775603e-02,  1.00000000e+00]])

# %%
theta=np.random.randn(2,1)
theta
# Out:
# array([[-0.26068633],
#        [ 0.11539152]])

# %%
def model (X,theta):
    return X.dot(theta)

# %%
plt.scatter (x,y)
plt.plot(x,model(X,theta), c='r')

# %% [markdown]
# # Fonction cout

# %%
def cost_function (X,y,theta):
    m=len(y)
    return 1/(2*m) * np.sum((model(X,theta)-y)**2)

# %%
cost_function(X,y,theta)
# Out:
# np.float64(1496.36671489252)

# %% [markdown]
# # Gradient

# %%
def gradient(X,y,theta):
    m=len(y)
    return 1/m * X.T.dot(model(X,theta)-y)

# %% [markdown]
# # Gradient descent

# %%
def gradiant_descent( X,y,theta, rate, n_iterations):
    cost_history=np.zeros(n_iterations)
    i = 0
    while i < n_iterations:
        theta=theta- rate*gradient(X,y,theta)  
        cost_history[i]=cost_function(X,y,theta)
        i = i + 1
    return theta,cost_history

# %% [markdown]
# ## Execution

# %%
theta_final,cost_history =gradiant_descent(X,y,theta, rate=0.01,n_iterations=1000)

# %%
theta_final
# Out:
# array([[33.89650236],
#        [-1.03175679]])

# %%
predictions=model(X,theta_final)
plt.scatter (x,y)
plt.plot(x,predictions, c='r')

# %%
plt.plot(range(1000),cost_history)

# %% [markdown]
# ## Coeff determination

# %%
def coef_determination(y,pred):
    u=((y-pred)**2).sum()
    v=((y -np.mean(y))**2).sum()
    return 1 - u/v

# %%
print(coef_determination(y,predictions))
# Out:
# 0.9677935800506818
